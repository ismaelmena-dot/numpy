# %% [markdown]
# # Hola Cientificos

# %%
import random

# %%
def generar_matriz(N):
    matriz= []
    for i in range (N):
        fila = []
        for j in range(N):
            fila.append(random.randint(1, 9))
        matriz.append(fila)
    return matriz

N = 5

matriz_aleatoria = generar_matriz(N)
for fila in matriz_aleatoria:
    print(fila)

def imprimir_matriz(matriz):
    for fila in matriz:
        fila_formateada = ' '.join(f'{elemento:2}' for elemento in fila)
        print(fila_formateada)
# Out:
# [5, 9, 1, 7, 9]
# [5, 2, 4, 1, 7]
# [5, 5, 1, 6, 9]
# [2, 1, 9, 7, 1]
# [3, 1, 3, 1, 9]

# %%
print("Matriz de 5x5")
m_5 = generar_matriz(5)
imprimir_matriz(m_5)
print("============")
print("Matriz de 10x10")
m_10 = generar_matriz(10)
imprimir_matriz(m_10)
print("============")
print("Matriz de 20x20")
m_20 = generar_matriz(20)
imprimir_matriz(m_20)
# Out:
# Matriz de 5x5
#  2  4  1  9  8
#  6  6  3  6  8
#  4  2  9  4  3
#  4  5  6  7  5
#  2  7  8  8  9
# ============
# Matriz de 10x10
#  8  1  1  2  4  2  4  1  6  1
#  2  3  3  6  3  6  4  1  4  2
#  1  6  5  2  3  5  4  9  7  4
#  5  2  6  4  7  8  3  7  7  4
#  3  9  9  4  2  5  5  3  3  2
#  9  7  9  2  3  7  4  8  2  3
#  3  8  9  2  9  1  7  7  2  1
#  2  6  8  9  3  3  9  4  6  4
#  7  9  7  8  4  6  9  3  4  5
#  1  9  1  9  9  8  6  1  4  4
# ============
# Matriz de 20x20
#  8  6  4  2  4  5  8  9  3  1  2  5  1  3  3  4  7  8  9  8
#  1  8  6  5  7  2  9  2  4  1  2  6  5  5  4  3  1  3  9  1
#  3  3  8  8  8  8  4  6  3  3  9  5  7  2  7  3  3  6  1  2
#  7  9  5  9  7  3  3  5  5  4  3  1  2  2  2  6  5  9  9  7
#  3  3  8  9  6  7  5  7  4  2  7  7  2  9  3  7  3  8  2  3
#  3  3  2  5  5  6  9  9  3  1  6  6  7  7  9  3  4  7  8  9
#  2  7  9  2  6  1  8  7  7  6  1  1  3  7  3  8  1  7  3  9
#  8  2  2  4  4  7  6  6  4  4  5  8  3  5  9  5  6  8  7  3
#  2  8  1  9  2  5  3  8  5  9  3  6  7  7  5  3  4  9  6  8
#  4  4  6  6  3  7  5  6  4  2  8  6  4  8  4  8  3  9  3  5
#  9  4  4  9  3  3  9  6  6  1  3  2  9  2  9  1  2  7  1  6
#  1  7  1  5  2  9  6  1  1  1  2  5  4  5  5  3  1  7  1  3
#  6  2  7  8  6  9  6  9  1  1  1  2  2  3  5  7  5  5  7  1
#  2  3  3  4  8  7  5  5  1  1  1  9  5  7  1  3  2  9  8  3
#  3  3  6  7  4  5  6  4  4  1  2  9  1  8  2  8  3  3  5  3
#  3  7  1  9  2  2  9  8  6  1  4  9  4  4  1  4  6  1  3  3
#  9  9  3  4  4  3  3  8  7  9  3  2  2  8  6  2  9  7  1  6
#  9  8  1  1  4  6  9  2  9  7  7  7  5  9  3  4  2  9  7  7
#  5  8  3  1  9  1  6  1  4  4  4  6  8  2  4  1  2  1  8  4
#  2  3  3  6  9  8  2  7  2  3  4  3  9  1  7  7  7  1  5  7
